# %%
import pandas as pd
import sql_functions as sf
from IPython.display import clear_output

engine = sf.get_engine()
 
schema = "bgg_data"

# %%
sql = f'''SELECT * FROM {schema}.honor;
      '''
df = sf.get_dataframe(sql)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/neesql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1808, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1807     if not evt_handled:
# -> 1808         self.dialect.do_execute(
#    1809             cursor, statement, parameters, context
#    1810         )
#    1812 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/neesql/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "bgg_data.honor" does not exist
# ...

# %%
winner_alt = ["Winnder","d'Or","Best","WInner","Winners","Award",'Inductee']
df[df['placement'].isin(winner_alt)] = "Winner"

# %%
df[df['placement'] == "Winner"]
# Out:
#            id cat_id                                           cat_name  year  \
# 14      17815   8796           Spiel des Jahres "Beautiful Game" Winner  1982
# 18      17904   8797           Spiel des Jahres "Beautiful Game" Winner  1983
# 21      17970  20874  Origins Awards Gamer’s Choice Best Historical ...  2005
# 37     306709  64021                   Ion Award Best Light Game Winner  2019
# 39     306735  70474            Golden Geek Best Solo Board Game Winner  2020
# ...       ...    ...                                                ...   ...
# 14203  218208  64077        Gra Roku Children's Game of the Year Winner  2018
# 14207  218333  64393  Boardgames Australia Awards Best Children's Ga...  2018
# 14209  218333  55637  UK Games Expo Best Children's Game People's Ch...  2018
# 14211  218333  64330            Guldbrikken Best Children's Game Winner  2019
# 14212  250821  57075  UK Games Expo Best Miniatures Rules People's C...  2019
#
#       placement
# ...

# %%
mask = df['placement'] == 'Place'

df.loc[mask, "placement"] = df["cat_name"].str.split().str[-2:].str.join(" ")

# %%
df
# Out:
#            id cat_id                                      cat_name  year  \
# 0      173003  64165       MinD-Spielepreis 2 Players Game Nominee  2019
# 1      173090  63956                 Fairplay À la carte Runner-up  2015
# 2      173090  34503            Golden Geek Best Card Game Nominee  2015
# 3      173090  34509      Golden Geek Best Solo Board Game Nominee  2015
# 4      173090  27370                      Spiel des Jahres Nominee  2015
# ...       ...    ...                                           ...   ...
# 14223  298069  75641   Cardboard Republic Daredevil Laurel Nominee  2021
# 14224  298069  75914   Golden Geek Medium Game of the Year Nominee  2021
# 14225  298102  75905     Golden Geek Best Cooperative Game Nominee  2021
# 14226  298102  75910  Golden Geek Best Thematic Board Game Nominee  2021
# 14227  298145  65000   Spiel der Spiele Hit für Kinder Recommended  2020
#
#          placement
# 0          Nominee
# 1        Runner-up
# 2          Nominee
# ...

# %%
df['placement'].unique()
# Out:
# array(['Nominee', 'Runner-up', 'Finalist', 'Recommended', 'Winner',
#        '3rd Place', 'Two-players', "d'Argent", 'Game', '2nd Place',
#        'Year', 'Bronze', 'Third Place', 'Second Place', 'Multi-player',
#        'Beginners', 'Simulation', 'Project', 'Québec', 'Nominees',
#        'Illustrations', 'Ano', 'Nomiee', 'Prize', 'Boardgame',
#        'Mechanics', 'Mention', 'Experts', 'Art', 'Game)', 'Two-player',
#        'year'], dtype=object)

# %%
filter_list = ['Award, Inductee','Game','Two-players','Year','Multi-player','Beginners', 'Simulation',
       'Project', 'Québec','Illustrations', 'Ano','Prize', 'Boardgame', 'Mechanics','Experts', 'Art', 'Game)', 'Two-player', 'year']

mask = df['placement'].isin(filter_list) 

df.loc[mask, :].to_csv('temp_csv.csv')

df.loc[mask, :]
# Out:
#          id cat_id                                           cat_name  year  \
# 108     638  12960  International Gamers Award - General Strategy:...  2001
# 408    1234  12636              Fall Lucca Games Best Translated Game  1996
# 418    1261  12528                   Lucca Games Best Translated Game  2001
# 445    1353  13374      Australian Games Association Game of the Year  2000
# 455    1362  13373      Australian Games Association Game of the Year  2001
# ...     ...    ...                                                ...   ...
# 13966   232  12634                Fall Lucca Games Best Original Game  1996
# 14000   295  12620                Fall Lucca Games Best Original Game  1998
# 14031   352  13391                  Games Magazine - Game of the year  1991
# 14039   372  12959  International Gamers Awards - General Strategy...  2000
# 14111  4396  12962  International Gamers Award - General Strategy:...  2003
#
#          placement
# 108    Two-players
# ...

# %%
df_temp = pd.read_csv('honor_changed_by_hand.csv')

df_temp = df_temp.set_index('Unnamed: 0')
df_temp.index.name = None

# %%
df.loc[mask, 'placement'] = df_temp.placement

# %%
sql = f'''SELECT * FROM {schema}.honor_clean;
      '''
df = sf.get_dataframe(sql)

# %%
df.rename(columns={'to_check_only':'cat_name'}, inplace=True)

# %%
df["organization"] = df["cat_name"].str.split().str[:2].str.join(" ")

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos              honor_org honor_name  \
# 0           2019          4                {Mensa}       None
# ...

# %%
mask_1_list = ['MinD-Spielepreis 2', 'JoTa Best'
 'Lys Grand',
 'JUGuinho Children',
 'Mensa Recommended',
 'Kinderspielexperten "8-to-13-year-olds"',
 'Mensa Select',
 'Mensa Select',
 'Guldbrikken Best',
 'Kanga Best',
 'Kinderspielexperten "5-to-9-year-olds"',
 'MinD-Spielepreis Complex',
 'MinD-Spielepreis Nominee',
 'SXSW Best',
 'MinD-Spieletipp Nominee',
 'NZGA Children’s',
 'NZGA Teacher’s',
 'MinD-Spielepreis Short',
 'JUG Adult',
 'ENnie for',
 'Kanga Game',
 'JUGuinho Families',
 'JUG Game',
 'NZGA New',
 'Guldbrikken Special',
 'MinD-Spielepreis Winner',
 'IndieCade Best',
 'JoTa Highlights',
 "ENnie Judge's",
 'ENnies -',
 'NGZA Awards',
 'NZGA Awards',
 'NZGA Game',
 'ENnies Best',
 'H.G. Best',
 'MinD-Spieletipp Winner',
 'JUGuinho Best']
mask_3_list = ['Spiel des',
 'Kinderspiel des',
 'Juego del',
 'Charles S.',
 'International Gamers',
 'International Gamers',
 'UK Games',
 'Deutscher Spiele',
 'Japan Boardgame',
 'Spiel der',
 "Spring Parents'",
 'Dětská hra',
 'Dětská hra',
 'Boardgames Australia',
 'Fall Lucca',
 'Australian Games',
 'Jogo do',
 'RPC Fantasy',
 "SXSW Gamer's",
 'The Golden',
 'Kennerspiel des',
 'Swiss Gamers',
 'Spel van',
 'Scelto dai',
 'Premio Jugamos',
 'UK Game',
 'Best Australian',
 'Palme de',
 'Geek Media',
 'Spiel Des',
 'Walter Luc',
 'Oppenheim Toy']
mask_4_list = ['Board Game',
 'Hungarian Board',
 '2012 Boardgames',
 '2012 Boardgames',
 'Bulgarian Board',
 'James F.',
 'H.G. Wells',
 'Canadian Game',
 '2010 Premio',
 'American Tabletop',
 'Best New',
 'Fairplay À']
mask_5_list = ['Best Science', 'Diana Jones', 'SXSW Tabletop', 'Best Historical']
mask_6_list = []

# %%
""" org_list = df["organization"].unique()

org_iter = iter(org_list)
i = 0
choice = ""

while choice != "exit":    
    choice = input("What would you like to do")
    if choice == '1':
        mask_1_list.append(org_list[i-1])
    elif choice == '3':
        mask_3_list.append(org_list[i-1])
    elif choice == '4':
        mask_4_list.append(org_list[i-1])
    elif choice == '5':
        mask_5_list.append(org_list[i-1])
    elif choice == '6':
        mask_5_list.append(org_list[i-1])
    elif choice == '': 
        mask_check = df["organization"].isin([next(org_iter)])
        i += 1 
    display(df.loc[mask_check, :])
    clear_output(wait=True)    """

# 'a'

mask_6_list
# Out:
# []

# %%
mask_3 = df["organization"].isin(mask_3_list)

mask_4 = df["organization"].isin(mask_4_list)

mask_1 = (df["organization"].str.startswith('JUGuinho') | df["organization"].isin(mask_1_list)).fillna(False)



df.loc[mask_3, "organization"] = df["cat_name"].str.split().str[:3].str.join(" ")

df.loc[mask_4, "organization"] = df["cat_name"].str.split().str[:4].str.join(" ")
df.loc[mask_1, "organization"] = df["cat_name"].str.split().str[0]

# %%
df["organization"].unique()
# Out:
# array(['MinD-Spielepreis', 'Fairplay À la carte', 'Golden Geek',
#        'Spiel des Jahres', 'Lys Grand', 'JUGuinho', 'Cardboard Republic',
#        'Origins Awards', 'Mensa', 'Kinderspiel des Jahres', '5 Seasons',
#        'Juego del Año', 'Kinderspielexperten', 'Årets Spill',
#        'Charles S. Roberts', "Meeples' Choice", 'Ion Award',
#        'International Gamers Award', 'UK Games Expo',
#        'Deutscher Spiele Preis', 'International Gamers Awards',
#        'Japan Boardgame Prize', 'Winner', 'Tric Trac', 'Games Magazine',
#        'Årets Spel', 'Årets Spil', 'Vuoden Peli',
#        'Board Game Quest Awards', 'Gouden Ludo',
#        'Nederlandse Spellenprijs', 'Spiel der Spiele', "Fall Parents'",
#        'Le Lys', 'Lys Enfant', "Spring Parents' Choice",
#        'Deutscher Lernspielpreis', 'Gra Roku', 'Guldbrikken',
#        'Hungarian Board Game Award', 'Zenobia Award', "GEEKS d'OURO",
#        'Kanga', 'Gioco dell’Anno', 'Dětská hra roku',
# ...

# %%
df['prize_name'] = df['cat_name']

# %%
mask_list = ['Årets Spil','Årets Spel','Arets Spel']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Årets Spill'

# %%
mask_list = ['Fall Lucca Games','Lucca Game','Gioco dell’Anno']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Lucca Games'

# %%
#Québec Association for Board Games Promotion

mask_list = ['Lys','Le Lys','Lys Enfant','Lys Passioné']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Québec Association for Board Games Promotion'

# %%
mask_list = ['MinD-Spielepreis','MinD-Spieletipp']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Mensa'

# %%
mask_list = ["Palme d'Or",'Palme de Bronze',"Palme d'Argent"]

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Palmes des Jeux'

# %%
mask_list = ["JUGuinho"]

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'JUG'

# %%
mask_list = ['Kinderspiel des Jahres','Kinderspiel des Jahren','Kennerspiel des Jahres','Spiel Des Jahres','Kinderspiel des Jahren','Spiel des Jahres']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Spiel des Jahres'

# %%
mask_list = ['Goblin Magnifico','Scelto dai Goblin']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Tana dei goblin'

# %%
mask_list = ['2012 Boardgames Australia Awards','Boardgames Australia Best','Best Australian Awards',]

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Boardgames Australia Awards'

# %%
mask_list = ['2010 Premio Jugamos Tod@s']

mask = df['organization'].isin(mask_list)

df.loc[mask,'organization'] = 'Premio Jugamos Tod@s'

# %%
df.organization.unique()
# Out:
# array(['Mensa', 'Fairplay À la carte', 'Golden Geek', 'Spiel des Jahres',
#        'Lys Grand', 'JUG', 'Cardboard Republic', 'Origins Awards',
#        '5 Seasons', 'Juego del Año', 'Kinderspielexperten', 'Årets Spill',
#        'Charles S. Roberts', "Meeples' Choice", 'Ion Award',
#        'International Gamers Award', 'UK Games Expo',
#        'Deutscher Spiele Preis', 'International Gamers Awards',
#        'Japan Boardgame Prize', 'Winner', 'Tric Trac', 'Games Magazine',
#        'Vuoden Peli', 'Board Game Quest Awards', 'Gouden Ludo',
#        'Nederlandse Spellenprijs', 'Spiel der Spiele', "Fall Parents'",
#        'Québec Association for Board Games Promotion',
#        "Spring Parents' Choice", 'Deutscher Lernspielpreis', 'Gra Roku',
#        'Guldbrikken', 'Hungarian Board Game Award', 'Zenobia Award',
#        "GEEKS d'OURO", 'Kanga', 'Lucca Games', 'Dětská hra roku',
#        'Boardgames Australia Awards', 'Tana dei goblin', 'Hra roku',
# ...

# %%
df['prize_name'] = df.apply(lambda row : row['prize_name'].replace(str(row['placement']), ''), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/neesql/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/neesql/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/neesql/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'placement'
#
# ...

# %%
df['prize_name'] = df.apply(lambda row : row['prize_name'].replace(str(row['organization']), ''), axis=1)

# %%
df.columns = ('id','honor_id','to_check_only','honor_year','honor_pos','honor_org','honor_name')

# %%
df['honor_pos'].unique()
# Out:
# array([4, 1, 3, 2])

# %%
position_dict = {

'Nominee': 4, 'Runner-up': 4, 'Finalist': 4, 'Recommended': 4, 'Winner': 1,
       '3rd Place': 3, "d'Argent": 2, '2nd Place': 2, 'Bronze': 3, 'Third Place': 3,
       'Second Place': 2, '3rd place': 3, 'Nominees': 4, '2nd place': 2, 'Nomiee': 4,
       'Mention': 4}

# %%
df2= df.replace({"honor_pos": position_dict})

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos              honor_org honor_name  \
# 0           2019          4                {Mensa}       None
# ...

# %%
df.drop(['honor_org','honor_name'],axis=1,inplace=True)

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
df['prize_name'] = df['prize_name'].str.strip()
df['organization'] = df['organization'].str.strip()

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
df['position_str'] = df['prize_name'].str.split().str[-1:].str.join(" ")

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
df['prize_name'] = df.apply(lambda row : row['prize_name'].replace(str(row['position_str']), ''), axis=1)

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
mask = df['prize_name'] == ''

df.loc[mask,'prize_name'] = df['organization']

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
df['prize_name'] = df['prize_name'].str.strip()
df['organization'] = df['organization'].str.strip()
df['position_str'] = df['position_str'].str.strip()

# %%
df
# Out:
#            id honor_id                                      cat_name  \
# 0      173003    64165       MinD-Spielepreis 2 Players Game Nominee
# 1      173090    63956                 Fairplay À la carte Runner-up
# 2      173090    34503            Golden Geek Best Card Game Nominee
# 3      173090    34509      Golden Geek Best Solo Board Game Nominee
# 4      173090    27370                      Spiel des Jahres Nominee
# ...       ...      ...                                           ...
# 14223  298069    75641   Cardboard Republic Daredevil Laurel Nominee
# 14224  298069    75914   Golden Geek Medium Game of the Year Nominee
# 14225  298102    75905     Golden Geek Best Cooperative Game Nominee
# 14226  298102    75910  Golden Geek Best Thematic Board Game Nominee
# 14227  298145    65000   Spiel der Spiele Hit für Kinder Recommended
#
#       honor_year  honor_pos         organization  \
# 0           2019          4                Mensa
# ...

# %%
sf.build_table(engine=engine,table_name="honor_clean",dataframe=df,schema=schema)
# Out:
# The honor_clean table was imported successfully.
