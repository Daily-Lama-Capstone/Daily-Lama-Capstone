# %%
import pandas as pd
import requests
import xml.etree.ElementTree as Etree

# %%
df = pd.read_xml("https://boardgamegeek.com/xmlapi2/thing?id=23451&stats=1")

df.head()
# Out:
#         type     id                                          thumbnail  \
# 0  boardgame  23451  https://cf.geekdo-images.com/0oURThe-6wuCft4vj...
#
#                                                image  name  \
# 0  https://cf.geekdo-images.com/0oURThe-6wuCft4vj...   NaN
#
#                                          description  yearpublished  \
# 0  Space Dealer is played in real time to a 30-mi...            NaN
#
#    minplayers  maxplayers  poll  playingtime  minplaytime  maxplaytime  \
# 0         NaN         NaN   NaN          NaN          NaN          NaN
#
#    minage  link  statistics
# 0     NaN   NaN         NaN

# %%
total_games = pd.DataFrame()
url = "https://boardgamegeek.com/xmlapi/boardgame/"
game_ids = list(range(1,20000))
for game_id in game_ids:
    # Create final url
    url_f = url + str(game_id)
    df_game = pd.read_xml(url_f)
    total_games = pd.concat([total_games, df_game], ignore_index=True)
total_games
# Out:
#        objectid  yearpublished  minplayers  maxplayers  playingtime  \
# 0           1.0         1986.0         3.0         5.0        240.0
# 1           2.0         1981.0         3.0         4.0         30.0
# 2           3.0         1998.0         2.0         4.0         60.0
# 3           4.0         1992.0         2.0         4.0         60.0
# 4           5.0         1964.0         2.0         6.0         90.0
# ...         ...            ...         ...         ...          ...
# 19994   19995.0         2006.0         2.0         5.0         90.0
# 19995   19996.0         2005.0         2.0         4.0         20.0
# 19996   19997.0         2005.0         1.0         5.0         15.0
# 19997   19998.0         2005.0         3.0         5.0         15.0
# 19998   19999.0         2005.0         2.0         2.0         30.0
#
#        minplaytime  maxplaytime   age                        name  \
# 0            240.0        240.0  14.0                        디 마허
# 1             30.0         30.0  12.0                Dragonmaster
# 2             30.0         60.0  10.0                        사무라이
# 3             60.0         60.0  12.0              Tal der Könige
# 4             90.0         90.0  12.0                       Trust
# ...            ...          ...   ...                         ...
# 19994         90.0         90.0  12.0                 Canal Mania
# 19995         10.0         20.0   5.0                  Ночь магов
# 19996         15.0         15.0   5.0  Mettiamoci al sole, Piuma!
# 19997         15.0         15.0   8.0                ZwergeZocken
# 19998         30.0         30.0   8.0                        Aton
#
#                                              description  ...  \
# 0      Die Macher is a game about seven sequential po...  ...
# 1      Dragonmaster is a trick-taking card game based...  ...
# 2      Samurai is set in medieval Japan. Players comp...  ...
# 3      When you see the triangular box and the luxuri...  ...
# 4      In Acquire, each player strategically invests ...  ...
# ...                                                  ...  ...
# 19994  Canal Mania is a game about the great canal-bu...  ...
# 19995  The basic premise is simple: the board, restin...  ...
# 19996  It's summer on the North Pole, and Lars and hi...  ...
# 19997  A trick-taking card game with 60 cards.<br/><br/>  ...
# 19998  From Queen Games website:<br/><br/>The whole o...  ...
#
#       vgcharacterversion rpgissuearticle boardgamewriter rpgartist  \
# 0                    NaN             NaN             NaN       NaN
# 1                    NaN             NaN             NaN       NaN
# 2                    NaN             NaN             NaN       NaN
# 3                    NaN             NaN             NaN       NaN
# 4                    NaN             NaN             NaN       NaN
# ...                  ...             ...             ...       ...
# 19994                NaN             NaN             NaN       NaN
# 19995                NaN             NaN             NaN       NaN
# 19996                NaN             NaN             NaN       NaN
# 19997                NaN             NaN             NaN       NaN
# 19998                NaN             NaN             NaN       NaN
#
#       rpgpublisher rpggenre rpgdesigner rpgproducer rpgcategory rpgitemversion
# 0              NaN      NaN         NaN         NaN         NaN            NaN
# 1              NaN      NaN         NaN         NaN         NaN            NaN
# 2              NaN      NaN         NaN         NaN         NaN            NaN
# 3              NaN      NaN         NaN         NaN         NaN            NaN
# 4              NaN      NaN         NaN         NaN         NaN            NaN
# ...            ...      ...         ...         ...         ...            ...
# 19994          NaN      NaN         NaN         NaN         NaN            NaN
# 19995          NaN      NaN         NaN         NaN         NaN            NaN
# 19996          NaN      NaN         NaN         NaN         NaN            NaN
# 19997          NaN      NaN         NaN         NaN         NaN            NaN
# 19998          NaN      NaN         NaN         NaN         NaN            NaN
#
# [19999 rows x 58 columns]

# %%
df_total
# Out:
#    objectid  yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0         1           1986           3           5          240          240
# 0         2           1981           3           4           30           30
# 0         3           1998           2           4           60           30
# 0         4           1992           2           4           60           60
# 0         5           1964           2           6           90           90
# 0         6           1989           2           6          240          240
# 0         7           1978           2           2           20           20
# 0         8           1993           2           5          120          120
# 0         9           1998           2           4           90           90
# 0        10           1998           2           6           60           60
# 0        11           1997           2           7           45           45
# 0        12           1999           2           5           60           45
# 0        13           1995           3           4          120           60
# 0        14           1998           3           4           25           25
# 0        15           1977           2           6           90           90
# 0        16           1996           3           4           60           60
# 0        17           1999           2           2            5            5
# 0        18           1994           2           8          120           45
# 0        19           1991           2           4           45           30
#
#    maxplaytime  age                               name  \
# 0          240   14                               디 마허
# 0           30   12                       Dragonmaster
# 0           60   10                               사무라이
# 0           60   12                     Tal der Könige
# 0           90   12                              Trust
# 0          240   12                 Mare Mediterraneum
# 0           20    8                   Monumental Moves
# 0          120   12                  Lords of Creation
# 0           90   13                       Conquistador
# 0           60   10  Elfenland (Волшебное Путешествие)
# 0           45   13                                보난자
# 0           60   12                              태양신 라
# 0          120   10                            카탄의 개척자
# 0           25   10                                バザリ
# 0           90   12                Universums härskare
# 0           60   12                          MarraCash
# 0            5   10                          Buttonmen
# 0          120   12                          RoboRally
# 0           45    9                   Wacky Wacky West
#
#                                          description  ... poll  \
# 0  Die Macher is a game about seven sequential po...  ...  NaN
# 0  Dragonmaster is a trick-taking card game based...  ...  NaN
# 0  Samurai is set in medieval Japan. Players comp...  ...  NaN
# 0  When you see the triangular box and the luxuri...  ...  NaN
# 0  In Acquire, each player strategically invests ...  ...  NaN
# 0  In the ancient lands along the Mediterranean, ...  ...  NaN
# 0  In Cathedral, each player has a set of pieces ...  ...  NaN
# 0  In this interesting offering from Warfrog, pla...  ...  NaN
# 0  Although referred to as a sequel to El Grande,...  ...  NaN
# 0  Elfenland is a redesign of the original White ...  ...  NaN
# 0  Bohnanza is the first in the Bohnanza family o...  ...  NaN
# 0  Ra is an auction and set-collection game with ...  ...  NaN
# 0  In CATAN (formerly The Settlers of Catan), pla...  ...  NaN
# 0  Basari is a game of gem merchants competing in...  ...  NaN
# 0  By request of Fantasy Flight Games, Board Game...  ...  NaN
# 0  Taking on the roles of shop owners in the Moro...  ...  NaN
# 0  This game gained a quick following after one o...  ...  NaN
# 0  The robots of the Robo Rally automobile factor...  ...  NaN
# 0  A long time ago, in a village far, far away, s...  ...  NaN
#
#   boardgameimplementation boardgamegraphicdesigner  \
# 0                     NaN                      NaN
# 0             Coup d'État                      NaN
# 0  Samurai: The Card Game           Monica Helland
# 0                     NaN                      NaN
# 0                     NaN                      NaN
# 0                     NaN                      NaN
# 0                     NaN                      NaN
# 0                     NaN                      NaN
# 0                     NaN                      NaN
# 0              Elfenroads                      NaN
# 0       Wendy Pferdebasar                      NaN
# 0                 Razzia!        Samuel R. Shimota
# 0              Wien Catan                      NaN
# 0     Edel, Stein & Reich                      NaN
# 0   Cosmic Encounter Duel                      NaN
# 0  Bazar der edlen Steine                      NaN
# 0                Dogfight                      NaN
# 0              Robo Rally                      NaN
# 0                     NaN                      NaN
#
#                      videogamebg boardgamedeveloper  \
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                     Shogun Hex       Jason Walden
# 0                            NaN                NaN
# 0               Computer Acquire         Nate Heiss
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                       Bohnanza                NaN
# 0             Reiner Knizia's Ra       Jason Walden
# 0           Catan: The Seafarers                NaN
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                            NaN                NaN
# 0                     Button Men                NaN
# 0  Robot Rally: Board game chaos                NaN
# 0                            NaN                NaN
#
#                                boardgameexpansion  \
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0   Wild Tile Variant Kit for the Game of ACQUIRE
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0  Stadt Land Spielt Limitierte Sonderdrucke 2013
# 0                                        Telebohn
# 0                                             NaN
# 0         World Wonders (fan expansion for Catan)
# 0                                             NaN
# 0             Rencontre Cosmique: Extension No. 1
# 0                                             NaN
# 0                                             NaN
# 0                          RoboRally: Radioactive
# 0                                             NaN
#
#                           boardgameaccessory  \
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                Acquire: Insert Here Insert
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                        Bohnanza: Sammelbox
# 0                         Ra: GeekUp Bit Set
# 0  Die Siedler von Catan: Der Catanische Rat
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
#
#                        commerceweblink   boardgamecompilation  \
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0  Geek Game Shop listing for Bohnanza                    NaN
# 0                                  NaN                    NaN
# 0  Geek Game Shop listing for Catan 5E  The Settlers of Catan
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
# 0                                  NaN                    NaN
#
#                   boardgameintegration
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0                                  NaN
# 0  Sailor Moon Crystal: Dice Challenge
# 0                                  NaN
# 0                                  NaN
#
# [19 rows x 32 columns]

# %%
df_kaggle = pd.read_csv("data/bgg_dataset.csv", sep=";")

# %%
df_kaggle.sort_values("Rating Average", ascending= False).head(20)
# Out:
#              ID                                               Name  \
# 14596  275777.0                                              Erune
# 11687  322354.0                                           DEFCON 1
# 10246  275972.0        Star Trek: Alliance - Dominion War Campaign
# 16310  228370.0                                        TerroriXico
# 13547  281257.0                                             Aeolis
# 11480  281515.0                                  Company of Heroes
# 7191    85147.0                            Wings of the Motherland
# 12244  273814.0                                        Deliverance
# 15784  207203.0                     War Titans: Invaders Must Die!
# 9940   283137.0                    Human Punishment: The Beginning
# 11470  292099.0                                              Sheol
# 14123  151070.0                                        Gladiatoris
# 13399  317511.0                                            Tindaya
# 15278  211693.0                                 Thug Life the Game
# 12143  293981.0         The Adventure Zone: Bureau of Balance Game
# 14545  260037.0                                        Composition
# 16308  284111.0                                   Drinks & Daggers
# 13503  310846.0                                            Urgency
# 8018   285853.0                                  Infinity Defiance
# 6681   148213.0  Primer: The Gamer's Source for Battles from th...
#
#        Year Published  Min Players  Max Players  Play Time  Min Age  \
# 14596             0.0            2            5        120       12
# 11687          2021.0            2            5        180       14
# 10246          2021.0            1            2         30       14
# 16310          2017.0            2            4         30       10
# 13547          2020.0            1            7        120       18
# 11480          2020.0            2            4         90       12
# 7191           2019.0            2            8        240       14
# 12244          2020.0            1            4        120       13
# 15784             0.0            1            4        120       13
# 9940           2021.0            3            6        180       14
# 11470          2021.0            1            4        120       12
# 14123          2009.0            1            6        180       12
# 13399             0.0            1            4        120       13
# 15278             0.0            2            5         60       16
# 12143          2020.0            2            5         90       12
# 14545          2020.0            2            5         60        8
# 16308          2019.0            2            6         30       21
# 13503          2020.0            2            2         45       10
# 8018           2020.0            1            4         60       14
# 6681           2013.0            2            6        120       14
#
#        Users Rated Rating Average  BGG Rank Complexity Average  Owned Users  \
# 14596           31           9,58     14598                  0         10.0
# 11687           57           9,54     11689                  3         12.0
# 10246           54           9,46     10248               3,29        117.0
# 16310           70           9,43     16312               2,50         35.0
# 13547           37           9,43     13549                  2         15.0
# 11480           47           9,34     11482               2,90        122.0
# 7191            79           9,31      7193               4,36        211.0
# 12244           34           9,25     12246                  0          9.0
# 15784           58           9,24     15786                  3          5.0
# 9940            39           9,24      9942               2,92         57.0
# 11470           64           9,23     11472               3,88         34.0
# 14123           31           9,23     14125               2,80          7.0
# 13399           30           9,22     13401               3,40          0.0
# 15278           46           9,21     15280                  3         55.0
# 12143           85           9,19     12145               1,60        254.0
# 14545           34           9,19     14547                  1         44.0
# 16308           57           9,18     16310                  2         83.0
# 13503           36           9,18     13505                  2         50.0
# 8018            89           9,16      8020               3,50        123.0
# 6681            58           9,14      6683                  4        255.0
#
#                                                Mechanics  \
# 14596  Action Points, Dice Rolling, Modular Board, Pa...
# 11687                             Variable Player Powers
# 10246                                   Cooperative Game
# 16310  Area Majority / Influence, Cooperative Game, D...
# 13547  Area Majority / Influence, Campaign / Battle C...
# 11480  Dice Rolling, Grid Movement, Hexagon Grid, Lin...
# 7191   Dice Rolling, Grid Movement, Hexagon Grid, Mov...
# 12244  Action Points, Campaign / Battle Card Driven, ...
# 15784  Cooperative Game, Hand Management, Point to Po...
# 9940   Area Movement, Dice Rolling, Hand Management, ...
# 11470  Action Points, Cooperative Game, Grid Movement...
# 14123  Dice Rolling, Grid Movement, Modular Board, Va...
# 13399  Area Majority / Influence, Cooperative Game, E...
# 15278  Area Majority / Influence, Dice Rolling, Simul...
# 12143  Cooperative Game, Critical Hits and Failures, ...
# 14545              Card Drafting, Variable Player Powers
# 16308  Cooperative Game, Hand Management, Role Playin...
# 13503  Card Drafting, Dice Rolling, Race, Roll / Spin...
# 8018   Campaign / Battle Card Driven, Cooperative Gam...
# 6681   Dice Rolling, Hexagon Grid, Line of Sight, Mov...
#
#                         Domains
# 14596                       NaN
# 11687                       NaN
# 10246                       NaN
# 16310                       NaN
# 13547                       NaN
# 11480                  Wargames
# 7191                   Wargames
# 12244                       NaN
# 15784                       NaN
# 9940                        NaN
# 11470                       NaN
# 14123  Strategy Games, Wargames
# 13399                       NaN
# 15278                       NaN
# 12143                       NaN
# 14545                       NaN
# 16308                       NaN
# 13503                       NaN
# 8018                        NaN
# 6681                   Wargames

# %%
bgg_games = pd.read_xml("https://boardgamegeek.com/xmlapi2/thing?id=23451&stats=1", p)

# %%
bgg_games
# Out:
#         type     id                                          thumbnail  \
# 0  boardgame  23451  https://cf.geekdo-images.com/0oURThe-6wuCft4vj...
#
#                                                image  name  \
# 0  https://cf.geekdo-images.com/0oURThe-6wuCft4vj...   NaN
#
#                                          description  yearpublished  \
# 0  Space Dealer is played in real time to a 30-mi...            NaN
#
#    minplayers  maxplayers  poll  playingtime  minplaytime  maxplaytime  \
# 0         NaN         NaN   NaN          NaN          NaN          NaN
#
#    minage  link  statistics
# 0     NaN   NaN         NaN
