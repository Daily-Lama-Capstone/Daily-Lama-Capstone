# %%
from sql_functions import get_dataframe
import pandas as pd
import numpy as np
# Import packages 
import numpy as np
import pandas as pd

# %%
schema = "bgg_data"


df_family = get_dataframe(f"SELECT * FROM {schema}.family_bgg")

df_main = get_dataframe(f"SELECT * FROM {schema}.unfiltered_main_stats_cleaned")

# %%
df_main
# Out:
#             id  yearpublished  min_players  max_players  playtime  \
# 0        98401         2010.0          2.0          4.0      30.0
# 1        98402         2011.0          2.0          5.0      30.0
# 2        98406         2011.0          2.0          4.0      30.0
# 3        98416         2007.0          2.0          4.0      50.0
# 4        98417         2009.0          2.0          2.0      60.0
# ...        ...            ...          ...          ...       ...
# 137142  298189         2020.0          3.0          7.0     120.0
# 137143  298190         2020.0          3.0          6.0      30.0
# 137144  298191         2022.0          2.0          5.0      80.0
# 137145  298193         2020.0          2.0          6.0      20.0
# 137146  298195         2020.0          1.0          4.0     120.0
#
#         min_playtime  max_playtime  min_age  average  user_rated  num_owned  \
# 0               30.0          30.0       10  7.08333           3         15
# ...

# %%
mask = df_main['id'] == 230802

df_main = df_main.drop_duplicates(subset='id')

# %%
df_kickstarter_bool = df_family.query('family_value == "kickstarter"')

# %%
df_kickstarter_bool.drop(['family_type','family_value','family_id'],axis=1,inplace=True)
# Out:
# /var/folders/rb/p48bcgy90nn3g9bz4kw5bh4w0000gn/T/ipykernel_6166/385456819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kickstarter_bool.drop(['family_type','family_value','family_id'],axis=1,inplace=True)

# %%
df_kickstarter_list = df_kickstarter_bool['id'].to_list()

# %%
df_kickstarter_list
# Out:
# [98443,
#  98527,
#  173005,
#  173018,
#  173024,
#  173057,
#  173058,
#  173059,
#  173070,
#  173072,
#  173073,
#  173075,
#  173093,
#  173105,
#  173108,
#  173109,
#  173110,
#  173115,
#  173117,
#  173129,
#  173130,
#  173131,
#  173148,
#  344233,
#  344235,
#  344240,
#  344247,
#  344268,
#  344269,
#  344274,
#  344280,
#  344292,
#  344308,
#  344341,
#  344345,
#  244212,
#  244231,
#  244236,
#  244241,
#  244250,
#  244258,
#  244268,
#  244271,
#  244301,
#  244302,
#  244304,
#  244305,
#  244338,
#  244352,
#  244358,
#  244367,
#  339227,
#  339251,
#  339258,
#  339296,
#  339302,
#  339336,
#  339340,
#  147420,
#  147428,
#  147431,
#  147437,
#  147445,
#  147465,
#  147505,
#  147522,
#  147552,
#  147598,
#  64826,
#  239241,
#  239242,
#  239244,
#  239246,
#  239262,
#  239277,
#  239288,
#  239290,
#  239291,
#  239292,
#  269831,
#  269887,
#  269955,
#  206664,
#  206681,
#  206757,
#  206778,
#  306621,
#  306623,
#  306634,
#  306636,
#  306637,
# ...

# %%
df_main['kickstarter'] = df_main['id'].isin(df_kickstarter_list)
# Out:
# /var/folders/rb/p48bcgy90nn3g9bz4kw5bh4w0000gn/T/ipykernel_6166/2466748162.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_main['kickstarter'] = df_main['id'].isin(df_kickstarter_list)

# %%
df_main
# Out:
#             id  yearpublished  min_players  max_players  playtime  \
# 0        98401         2010.0          2.0          4.0      30.0
# 1        98402         2011.0          2.0          5.0      30.0
# 2        98406         2011.0          2.0          4.0      30.0
# 3        98416         2007.0          2.0          4.0      50.0
# 4        98417         2009.0          2.0          2.0      60.0
# ...        ...            ...          ...          ...       ...
# 137142  298189         2020.0          3.0          7.0     120.0
# 137143  298190         2020.0          3.0          6.0      30.0
# 137144  298191         2022.0          2.0          5.0      80.0
# 137145  298193         2020.0          2.0          6.0      20.0
# 137146  298195         2020.0          1.0          4.0     120.0
#
#         min_playtime  max_playtime  min_age  average  user_rated  num_owned  \
# 0               30.0          30.0       10  7.08333           3         15
# ...
